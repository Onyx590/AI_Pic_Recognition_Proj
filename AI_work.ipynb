# %% [markdown]
# <a href="https://colab.research.google.com/github/Onyx590/AI_Pic_Recognition_Proj/blob/onyx_branch/AI_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
mkdir /content/dataset

# %% [markdown]
# Put the data in this folder manually ^

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 119344, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 119344 (delta 172), reused 131 (delta 126), pack-reused 119127 (from 2)
# Receiving objects: 100% (119344/119344), 93.48 MiB | 23.53 MiB/s, done.
# Resolving deltas: 100% (89505/89505), done.

# %%
# %cd diffusers
# Out:
# /content/diffusers

# %%
# !pip install .
# Out:
# Processing /content/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.37.0.dev0-py3-none-any.whl size=4893405 sha256=87ad9f9739e69d09ba3850b6cd4adcea2b7c02ca57b59f996adaa48aafb842ac
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s8za3jfg/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.36.0
#     Uninstalling diffusers-0.36.0:
#       Successfully uninstalled diffusers-0.36.0
# ...

# %%
# %cd examples/instruct_pix2pix
# Out:
# /content/diffusers/examples/instruct_pix2pix

# %%
# %cd ../
# Out:
# /content/diffusers/examples

# %%
# %cd examples/text_to_image
# Out:
# [Errno 2] No such file or directory: 'examples/text_to_image'
# /content/diffusers/examples

# %%
# %cd text_to_image/
# Out:
# /content/diffusers/examples/text_to_image

# %%
# !pip install -r requirements_sdxl.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# !pwd
# Out:
# /content/diffusers/examples/text_to_image

# %%
# %cd /content/dataset/
# Out:
# /content/dataset

# %%
# !pwd
# Out:
# /content/dataset

# %%
# !unzip picboost_final_train_dataset.zip
# Out:
# Archive:  picboost_final_train_dataset.zip
#   inflating: 5be2f045.jpg
#   inflating: fb3ddc1b.jpg
#   inflating: a9f2cbc5.jpg
#   inflating: 34204f40.jpg
#   inflating: 7a7f9756.jpg
#   inflating: 52b424eb.jpg
#   inflating: 2da45184.jpg
#   inflating: b5834cb2.jpg
#   inflating: 13f91077.jpg
#   inflating: cd175a5b.jpg
#   inflating: 4b92f374.jpg
#   inflating: c8e1bd38.jpg
#   inflating: ad5a3f13.jpg
#   inflating: 7a928de2.jpg
#   inflating: e5e2d460.jpg
#   inflating: 031dba03.jpg
#   inflating: 79b852aa.jpg
#   inflating: a7364c35.jpg
#   inflating: 7545b8c6.jpg
#   inflating: 7f69be09.jpg
#   inflating: 1662df33.jpg
#   inflating: dbaf9557.jpg
#   inflating: f58659f0.jpg
#   inflating: 358de357.jpg
#   inflating: 8daf6c61.jpg
#   inflating: 9d13111d.jpg
#   inflating: dc15d266.jpg
#   inflating: 573559bf.jpg
#   inflating: metadata.jsonl
#   inflating: b6525e3b.jpg
#   inflating: d98c9069.jpg
#   inflating: 6b2f002e.jpg
#   inflating: 98f5cc66.jpg
#   inflating: c5c6bca5.jpg
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !accelerate launch --mixed_precision="fp16" /content/diffusers/examples/text_to_image/train_text_to_image_lora_sdxl.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \
  --dataset_name="/content/dataset/" \
  --resolution=256 \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=2 \
  --gradient_checkpointing \
  --max_train_steps=7000 \
  --learning_rate=5e-05 \
  --max_grad_norm=1 \
  --lr_warmup_steps=0 \
  --mixed_precision=fp16 \
  --seed=42 \
  --rank=16
# Out:
# 2026-01-21 20:56:55.204371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769029015.246740    3771 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769029015.258174    3771 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769029015.287388    3771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r weights.zip sd-model-finetuned-lora/

# %%
from google.colab import files
files.download("weights.zip")
